# %%
import pandas as pd

# %%
data ={'state':['Ohio','Ohio',"Ohio","Nevade","Nevada","Nevada"],
      'year':[200,900,789,5678,9078,765],
       'pop':[1.2,1.4,1.2,1.5,1.6,1.7]
      }

# %%
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio   200  1.2
# 1    Ohio   900  1.4
# 2    Ohio   789  1.2
# 3  Nevade  5678  1.5
# 4  Nevada  9078  1.6
# 5  Nevada   765  1.7

# %%
frame1=pd.DataFrame(data,columns=['year','state','pop'])
frame1
# Out:
#    year   state  pop
# 0   200    Ohio  1.2
# 1   900    Ohio  1.4
# 2   789    Ohio  1.2
# 3  5678  Nevade  1.5
# 4  9078  Nevada  1.6
# 5   765  Nevada  1.7

# %%
frame1=pd.DataFrame(data,columns=['year','state','pop','extracolumn'])#add columns
frame1
# Out:
#    year   state  pop extracolumn
# 0   200    Ohio  1.2         NaN
# 1   900    Ohio  1.4         NaN
# 2   789    Ohio  1.2         NaN
# 3  5678  Nevade  1.5         NaN
# 4  9078  Nevada  1.6         NaN
# 5   765  Nevada  1.7         NaN

# %%
frame2=pd.DataFrame(data,columns=['year','state','pop'],index=[1,2,3,4,"ohho",1.1])
frame2
# Out:
#       year   state  pop
# 1      200    Ohio  1.2
# 2      900    Ohio  1.4
# 3      789    Ohio  1.2
# 4     5678  Nevade  1.5
# ohho  9078  Nevada  1.6
# 1.1    765  Nevada  1.7

# %%
frame1=pd.DataFrame(data,columns=['year','state','pop','debt'],index=['one','two','three',
                                                                      'four','five','six'])
frame1
# Out:
#        year   state  pop debt
# one     200    Ohio  1.2  NaN
# two     900    Ohio  1.4  NaN
# three   789    Ohio  1.2  NaN
# four   5678  Nevade  1.5  NaN
# five   9078  Nevada  1.6  NaN
# six     765  Nevada  1.7  NaN

# %%
frame1.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame1.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %% [markdown]
# # agar col name may space hoto dot wise nahi uthay ga otherwise uth gay ga

# %%
frame1['year']
# Out:
# one       200
# two       900
# three     789
# four     5678
# five     9078
# six       765
# Name: year, dtype: int64

# %%
frame1.year
# Out:
# one       200
# two       900
# three     789
# four     5678
# five     9078
# six       765
# Name: year, dtype: int64

# %%
val = pd.Series([-1.2,-1.5,-1.7],index=['one','two','five'])

# %%
val
# Out:
# one    -1.2
# two    -1.5
# five   -1.7
# dtype: float64

# %%
frame1.debt=val
frame1
# Out:
#        year   state  pop  debt
# one     200    Ohio  1.2  -1.2
# two     900    Ohio  1.4  -1.5
# three   789    Ohio  1.2   NaN
# four   5678  Nevade  1.5   NaN
# five   9078  Nevada  1.6  -1.7
# six     765  Nevada  1.7   NaN

# %%
frame7=pd.DataFrame(data,columns=['year','state','pop','economy'],index=[1,2,3,4,5,6])
frame7
# Out:
#    year   state  pop economy
# 1   200    Ohio  1.2     NaN
# 2   900    Ohio  1.4     NaN
# 3   789    Ohio  1.2     NaN
# 4  5678  Nevade  1.5     NaN
# 5  9078  Nevada  1.6     NaN
# 6   765  Nevada  1.7     NaN

# %%
val1=pd.Series([1,8,9,87])#neglect 0th index

# %%
frame7.economy=val1

# %%
frame7
# Out:
#    year   state  pop  economy
# 1   200    Ohio  1.2      8.0
# 2   900    Ohio  1.4      9.0
# 3   789    Ohio  1.2     87.0
# 4  5678  Nevade  1.5      NaN
# 5  9078  Nevada  1.6      NaN
# 6   765  Nevada  1.7      NaN

# %%
pop={'Nevanda':{2001:2.4,2002:2.5},
    'Ohio':{2001:2.1,2009:2.8,2010:2.7}}
frame8=pd.DataFrame(pop)

# %%
frame8
# Out:
#       Nevanda  Ohio
# 2001      2.4   2.1
# 2002      2.5   NaN
# 2009      NaN   2.8
# 2010      NaN   2.7

# %%
pd.DataFrame(pop,index=[2001,2002,2003])
# Out:
#       Nevanda  Ohio
# 2001      2.4   2.1
# 2002      2.5   NaN
# 2003      NaN   NaN

# %%
pdata={'Ohio':frame8['Ohio'][:-1],
      'Nevada':frame8['Nevanda'][:2]}

# %%
pdata
# Out:
# {'Ohio': 2001    2.1
#  2002    NaN
#  2009    2.8
#  Name: Ohio, dtype: float64, 'Nevada': 2001    2.4
#  2002    2.5
#  Name: Nevanda, dtype: float64}

# %%
pdata=pd.DataFrame(pdata)
pdata
# Out:
#       Ohio  Nevada
# 2001   2.1     2.4
# 2002   NaN     2.5
# 2009   2.8     NaN

# %%
frame8.index.name='year';frame8.columns.name='state'

# %%
frame8
# Out:
# state  Nevanda  Ohio
# year
# 2001       2.4   2.1
# 2002       2.5   NaN
# 2009       NaN   2.8
# 2010       NaN   2.7

# %%
frame8.values
# Out:
# array([[2.4, 2.1],
#        [2.5, nan],
#        [nan, 2.8],
#        [nan, 2.7]])

# %%
frame8.keys
# Out:
# <bound method NDFrame.keys of state  Nevanda  Ohio
# year
# 2001       2.4   2.1
# 2002       2.5   NaN
# 2009       NaN   2.8
# 2010       NaN   2.7>

# %%
frame8.items
# Out:
# <bound method DataFrame.iteritems of state  Nevanda  Ohio
# year
# 2001       2.4   2.1
# 2002       2.5   NaN
# 2009       NaN   2.8
# 2010       NaN   2.7>

# %% [markdown]
# # 5.2 Essential functionality

# %%
#Reindexing

# %%
obj=pd.Series([4.5,7.2,-5.3,3.6],index=['d','b','a','c'])

# %%
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2=obj.reindex(['a','b','c','d','e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj2=obj.reindex(['ali','ballon','cat','dog','egg'])
obj2
# Out:
# ali      NaN
# ballon   NaN
# cat      NaN
# dog      NaN
# egg      NaN
# dtype: float64

# %%
obj3=pd.Series(['blue','purple','yellow'],index=[0,2,4])

# %%
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
obj3.reindex(range(6))
# Out:
# 0      blue
# 1       NaN
# 2    purple
# 3       NaN
# 4    yellow
# 5       NaN
# dtype: object

# %% [markdown]
# #Its for removing NAN

# %%
obj3.reindex(range(6),method='ffill')#ffill means forward fill
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
obj3.reindex(range(6),method='bfill')#bfill means backward fill
# Out:
# 0      blue
# 1    purple
# 2    purple
# 3    yellow
# 4    yellow
# 5       NaN
# dtype: object

# %%
#reindexing on frame

# %%
import numpy as np
import pandas as pd

# %%
frame11 =pd.DataFrame(np.arange(9).reshape(3,3),
       index=['a','c','d'],
       columns=['Ohio','Texas','California'])
frame11
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame12=frame11.reindex(['a','b','c','d'])

# %%
frame12
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
states=['Ohio','Utah','California']
frame12.reindex(columns=states)
# Out:
#    Ohio  Utah  California
# a   0.0   NaN         2.0
# b   NaN   NaN         NaN
# c   3.0   NaN         5.0
# d   6.0   NaN         8.0

# %%
frame12.reindex(index=['f','b','c','d','g'],columns=['Texas','Newyork','Utah','California','Bay'])
# Out:
#    Texas  Newyork  Utah  California  Bay
# f    NaN      NaN   NaN         NaN  NaN
# b    NaN      NaN   NaN         NaN  NaN
# c    4.0      NaN   NaN         5.0  NaN
# d    7.0      NaN   NaN         8.0  NaN
# g    NaN      NaN   NaN         NaN  NaN

# %%
data = pd.DataFrame(np.arange(1,16).reshape((3,5)),columns=['a','b','c','d','e'])
data
# Out:
#     a   b   c   d   e
# 0   1   2   3   4   5
# 1   6   7   8   9  10
# 2  11  12  13  14  15

# %%
data1 = pd.DataFrame(np.arange(1,101).reshape((20,5)),columns=['a','b','c','d','e'])
data1
# Out:
#      a   b   c   d    e
# 0    1   2   3   4    5
# 1    6   7   8   9   10
# 2   11  12  13  14   15
# 3   16  17  18  19   20
# 4   21  22  23  24   25
# 5   26  27  28  29   30
# 6   31  32  33  34   35
# 7   36  37  38  39   40
# 8   41  42  43  44   45
# 9   46  47  48  49   50
# 10  51  52  53  54   55
# 11  56  57  58  59   60
# 12  61  62  63  64   65
# 13  66  67  68  69   70
# 14  71  72  73  74   75
# 15  76  77  78  79   80
# 16  81  82  83  84   85
# 17  86  87  88  89   90
# 18  91  92  93  94   95
# 19  96  97  98  99  100

# %%
data2 = pd.DataFrame(np.arange(1,101).reshape((20,5)),columns=['a','b','c','d','e'],index=range(1,101,5))
data2
# Out:
#      a   b   c   d    e
# 1    1   2   3   4    5
# 6    6   7   8   9   10
# 11  11  12  13  14   15
# 16  16  17  18  19   20
# 21  21  22  23  24   25
# 26  26  27  28  29   30
# 31  31  32  33  34   35
# 36  36  37  38  39   40
# 41  41  42  43  44   45
# 46  46  47  48  49   50
# 51  51  52  53  54   55
# 56  56  57  58  59   60
# 61  61  62  63  64   65
# 66  66  67  68  69   70
# 71  71  72  73  74   75
# 76  76  77  78  79   80
# 81  81  82  83  84   85
# 86  86  87  88  89   90
# 91  91  92  93  94   95
# 96  96  97  98  99  100

# %%
data3 = pd.DataFrame(np.arange(1,101).reshape((20,5)),columns=list('abcde'),index=range(1,101,5))
data3
# Out:
#      a   b   c   d    e
# 1    1   2   3   4    5
# 6    6   7   8   9   10
# 11  11  12  13  14   15
# 16  16  17  18  19   20
# 21  21  22  23  24   25
# 26  26  27  28  29   30
# 31  31  32  33  34   35
# 36  36  37  38  39   40
# 41  41  42  43  44   45
# 46  46  47  48  49   50
# 51  51  52  53  54   55
# 56  56  57  58  59   60
# 61  61  62  63  64   65
# 66  66  67  68  69   70
# 71  71  72  73  74   75
# 76  76  77  78  79   80
# 81  81  82  83  84   85
# 86  86  87  88  89   90
# 91  91  92  93  94   95
# 96  96  97  98  99  100

# %%
c =list('population')

# %%
c
# Out:
# ['p', 'o', 'p', 'u', 'l', 'a', 't', 'i', 'o', 'n']

# %%
#idex pata hae location nahi pata

# %%
frame12.loc['c']
# Out:
# Ohio          3.0
# Texas         4.0
# California    5.0
# Name: c, dtype: float64

# %%
frame12.loc['c']['Ohio']
# Out:
# 3.0

# %%
frame12.iloc[1]
# Out:
# Ohio         NaN
# Texas        NaN
# California   NaN
# Name: b, dtype: float64

# %%
frame12.iloc[2]
# Out:
# Ohio          3.0
# Texas         4.0
# California    5.0
# Name: c, dtype: float64

# %%
frame12.iloc[2]['Ohio']
# Out:
# 3.0

# %%
frame12.loc[::-1]
# Out:
#    Ohio  Texas  California
# d   6.0    7.0         8.0
# c   3.0    4.0         5.0
# b   NaN    NaN         NaN
# a   0.0    1.0         2.0

# %%
frame12.loc[::-1,::-1]
# Out:
#    California  Texas  Ohio
# d         8.0    7.0   6.0
# c         5.0    4.0   3.0
# b         NaN    NaN   NaN
# a         2.0    1.0   0.0

# %%
frame12.loc['a':'c']#it count last value
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0

# %%
frame12.iloc[0:2]#it does not count last value
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN

# %%
frame12.loc['b']['Ohio']=2

# %%
frame12
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   2.0    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame12.loc['b']=2

# %%
frame12
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   2.0    2.0         2.0
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame12.loc['c'][0]=334

# %%
frame12
# Out:
#     Ohio  Texas  California
# a    0.0    1.0         2.0
# b    2.0    2.0         2.0
# c  334.0    4.0         5.0
# d    6.0    7.0         8.0

# %%
frame12.loc['b'][0:2]=[4,6]

# %%
frame12
# Out:
#     Ohio  Texas  California
# a    0.0    1.0         2.0
# b    4.0    6.0         2.0
# c  334.0    4.0         5.0
# d    6.0    7.0         8.0

# %%
frame12.loc['b']
# Out:
# Ohio          4.0
# Texas         6.0
# California    2.0
# Name: b, dtype: float64

# %%
#swaping

# %%
frame12.loc['b'][[2,0]]
# Out:
# California    4.0
# Ohio          2.0
# Name: b, dtype: float64

# %%
frame12.loc['b'][[2,0]]=frame12.loc['b'][[0,2]]
frame12
# Out:
#     Ohio  Texas  California
# a    0.0    1.0         2.0
# b    2.0    6.0         4.0
# c  334.0    4.0         5.0
# d    6.0    7.0         8.0

# %%
frame12['Texas'][1]+5
# Out:
# 11.0

# %%
#NAn is not added with any number
#Nan by default float hota hae

# %%
frame13=frame12.copy()
frame13['std']=[4,5,6,7]
frame13
# Out:
#     Ohio  Texas  California  std
# a    0.0    1.0         2.0    4
# b    2.0    6.0         4.0    5
# c  334.0    4.0         5.0    6
# d    6.0    7.0         8.0    7

# %%
frame16=frame12+frame13
frame16
# Out:
#    California   Ohio  Texas  std
# a         4.0    0.0    2.0  NaN
# b         8.0    4.0   12.0  NaN
# c        10.0  668.0    8.0  NaN
# d        16.0   12.0   14.0  NaN

# %%
frame17=frame12+frame13
frame17
# Out:
#    California   Ohio  Texas  std
# a         4.0    0.0    2.0  NaN
# b         8.0    4.0   12.0  NaN
# c        10.0  668.0    8.0  NaN
# d        16.0   12.0   14.0  NaN

# %%
frame13[frame13 > 5]
# Out:
#     Ohio  Texas  California  std
# a    NaN    NaN         NaN  NaN
# b    NaN    6.0         NaN  NaN
# c  334.0    NaN         NaN  6.0
# d    6.0    7.0         8.0  7.0

# %%
frame12.loc['a':]
# Out:
#     Ohio  Texas  California
# a    0.0    1.0         2.0
# b    2.0    6.0         4.0
# c  334.0    4.0         5.0
# d    6.0    7.0         8.0

# %%
frame17.isnull()#check nan in the columns
# Out:
#    California   Ohio  Texas   std
# a       False  False  False  True
# b       False  False  False  True
# c       False  False  False  True
# d       False  False  False  True

# %%
frame16.fillna(0)#change in view not in memory or original(Its use)

# %%
#change in memory or original(Its not use)
frame16.fillna(0,inplace=True)#replace nan by default values

# %%
#good practice is that fill nan values by the average of column
#nan value replace by  0 is not good paractina

# %%
frame16
# Out:
#    California   Ohio  Texas  std
# a         4.0    0.0    2.0  0.0
# b         8.0    4.0   12.0  0.0
# c        10.0  668.0    8.0  0.0
# d        16.0   12.0   14.0  0.0

# %%
frame17.dropna('std')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-15d739416a91> in <module>
# ----> 1 frame17.dropna('std')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4570                                        axis=ax)
#    4571         else:
# -> 4572             axis = self._get_axis_number(axis)
#    4573             agg_axis = 1 - axis
#    4574
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     359                 pass
#     360         raise ValueError('No axis named {0} for object type {1}'
# --> 361                          .format(axis, type(cls)))
#     362
#     363     @classmethod
#
# ValueError: No axis named std for object type <class 'type'>

# %%
frame12.loc[:]
# Out:
#     Ohio  Texas  California
# a    0.0    1.0         2.0
# b    2.0    6.0         4.0
# c  334.0    4.0         5.0
# d    6.0    7.0         8.0

# %%
frame12.loc[:'d']
# Out:
#     Ohio  Texas  California
# a    0.0    1.0         2.0
# b    2.0    6.0         4.0
# c  334.0    4.0         5.0
# d    6.0    7.0         8.0

# %%
frame12.loc[:'d':-1]
# Out:
#    Ohio  Texas  California
# d   6.0    7.0         8.0

# %%
frame12.loc['a':'d':-1]
# Out:
# Empty DataFrame
# Columns: [Ohio, Texas, California]
# Index: []

# %%
frame12.loc['d'::-1]
# Out:
#     Ohio  Texas  California
# d    6.0    7.0         8.0
# c  334.0    4.0         5.0
# b    2.0    6.0         4.0
# a    0.0    1.0         2.0

# %%
frame12.loc[::-1]
# Out:
#     Ohio  Texas  California
# d    6.0    7.0         8.0
# c  334.0    4.0         5.0
# b    2.0    6.0         4.0
# a    0.0    1.0         2.0

# %%
frame12.loc[::-1,['Ohio']]
# Out:
#     Ohio
# d    6.0
# c  334.0
# b    2.0
# a    0.0

# %%
frame12.loc[::-1][:]
# Out:
#     Ohio  Texas  California
# d    6.0    7.0         8.0
# c  334.0    4.0         5.0
# b    2.0    6.0         4.0
# a    0.0    1.0         2.0

# %%
frame12.loc[::-1][1:]
# Out:
#     Ohio  Texas  California
# c  334.0    4.0         5.0
# b    2.0    6.0         4.0
# a    0.0    1.0         2.0

# %%
frame12.loc[::-1,'Texas'::]
# Out:
#    Texas  California
# d    7.0         8.0
# c    4.0         5.0
# b    6.0         4.0
# a    1.0         2.0

# %%
frame12.loc[::-1,'Texas'::-1]
# Out:
#    Texas   Ohio
# d    7.0    6.0
# c    4.0  334.0
# b    6.0    2.0
# a    1.0    0.0

# %%
frame12.loc[::-1,'Texas'::-2]
# Out:
#    Texas
# d    7.0
# c    4.0
# b    6.0
# a    1.0

# %%
frame12.loc[::-1,'California'::-2]
# Out:
#    California   Ohio
# d         8.0    6.0
# c         5.0  334.0
# b         4.0    2.0
# a         2.0    0.0

# %%
frame12.loc['b']=[3,4]
frame12
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-430fc8691eff> in <module>
# ----> 1 frame12.loc['b']=[3,4]
#       2 frame12
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     654             self.obj._consolidate_inplace()
#     655             self.obj._data = self.obj._data.setitem(indexer=indexer,
# --> 656                                                     value=value)
#     657             self.obj._maybe_update_cacher(clear=True)
#     658
#
# ...

# %%
csvdata=pd.read_csv('jTeOBO.csv')
csvdata.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
csvdata
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
frame=pd.DataFrame(csvdata)
#highestscore = Best of Quizess > 7
frame
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
frame['Best of Quizzes']
# Out:
# 0     8
# 1     5
# 2     5
# 3     7
# 4     7
# 5     9
# 6     6
# 7     9
# 8     9
# 9     8
# 10    8
# 11    8
# 12    7
# 13    8
# 14    7
# 15    0
# 16    5
# 17    8
# 18    5
# 19    9
# 20    7
# 21    9
# 22    7
# 23    5
# 24    5
# 25    9
# 26    6
# 27    8
# 28    6
# 29    7
# 30    8
# 31    7
# 32    2
# 33    4
# 34    9
# 35    8
# 36    9
# 37    9
# 38    6
# 39    4
# 40    9
# 41    7
# 42    6
# 43    9
# 44    7
# 45    9
# 46    8
# 47    9
# Name: Best of Quizzes, dtype: int64

# %%
frame[frame['Best of Quizzes']>7]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# ...

# %%
frame[frame['Best of Quizzes']>7].count()
# Out:
# Student Code            23
# Degree                  23
# Student Name            23
# Mid                     23
# Quiz 1                  23
# Quiz 2                  23
# Best of Quizzes         23
# Assignment 1            22
# Assignment 2            16
# Best of Assignments     23
# Total Sessional (50)    23
# Final (50)              23
# Total (100)             23
# Grade                   23
# dtype: int64

# %%
frame[(frame['Best of Quizzes']>7) & (frame['Best of Assignments']>7)].count()
# Out:
# Student Code            21
# Degree                  21
# Student Name            21
# Mid                     21
# Quiz 1                  21
# Quiz 2                  21
# Best of Quizzes         21
# Assignment 1            20
# Assignment 2            15
# Best of Assignments     21
# Total Sessional (50)    21
# Final (50)              21
# Total (100)             21
# Grade                   21
# dtype: int64

# %%
(frame['Best of Quizzes']>7) & (frame['Best of Assignments']>7)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27     True
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34     True
# 35     True
# 36     True
# 37     True
# 38    False
# 39    False
# 40     True
# 41    False
# 42    False
# 43     True
# 44    False
# 45     True
# 46     True
# 47    False
# dtype: bool

# %%
frame["Mid"][frame["Student Name"]=="Abdul Basit"]
# Out:
# 0    28
# Name: Mid, dtype: int64

# %%
import numpy as np

# %%
frame= pd.DataFrame(np.random.randn(4,3),columns=list('bde'),
                  index=["Utah","Ohio","California","Pakistan"])
frame
# Out:
#                    b         d         e
# Utah        1.635124 -0.864561 -0.989366
# Ohio        0.390315  1.280961  0.374696
# California -0.520728  0.143484 -0.176720
# Pakistan    0.384287 -0.586132 -0.132557

# %%
np.abs(frame)
# Out:
#                    b         d         e
# Utah        1.635124  0.864561  0.989366
# Ohio        0.390315  1.280961  0.374696
# California  0.520728  0.143484  0.176720
# Pakistan    0.384287  0.586132  0.132557

# %%
f=lambda x:x.max() -x.min()
frame.apply(f)
# Out:
# b    2.155852
# d    2.145521
# e    1.364062
# dtype: float64

# %%
f=lambda x:x**2
frame.apply(f)
# Out:
#                    b         d         e
# Utah        2.673630  0.747465  0.978845
# Ohio        0.152346  1.640860  0.140397
# California  0.271158  0.020588  0.031230
# Pakistan    0.147677  0.343550  0.017571

# %%
f=lambda x:x-2
frame.apply(f)
# Out:
#                    b         d         e
# Utah       -0.364876 -2.864561 -2.989366
# Ohio       -1.609685 -0.719039 -1.625304
# California -2.520728 -1.856516 -2.176720
# Pakistan   -1.615713 -2.586132 -2.132557

# %%
frame.max(axis=1)
# Out:
# Utah          1.635124
# Ohio          1.280961
# California    0.143484
# Pakistan      0.384287
# dtype: float64

# %%
frame.max()
# Out:
# b    1.635124
# d    1.280961
# e    0.374696
# dtype: float64

# %%
frame.max(axis=0)
# Out:
# b    1.635124
# d    1.280961
# e    0.374696
# dtype: float64

# %% [markdown]
# # Sorting and Ranking

# %%
obj = pd.Series(range(4),index=['a','b','c','d'])

# %%
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
obj.sort_index(ascending=False)
# Out:
# d    3
# c    2
# b    1
# a    0
# dtype: int64
