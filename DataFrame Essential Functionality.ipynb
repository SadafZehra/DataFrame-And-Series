# %% [markdown]
# # ESSENTIAL FUNCTIONALITY

# %%
import pandas as pd

# %%
df = pd.DataFrame(["Apple","Mangoes","Banana"])
df
# Out:
#          0
# 0    Apple
# 1  Mangoes
# 2   Banana

# %%
df = pd.DataFrame([["Apple"],["Mangoes"],["Banana"]])
df
# Out:
#          0
# 0    Apple
# 1  Mangoes
# 2   Banana

# %%
dict1={"City":["khi","lah","Isl","Quetta"]
      ,"Zip Code":[1,2,3,4],
      "Population":['1234','65768','56743','2345']}
dict1
# Out:
# {'City': ['khi', 'lah', 'Isl', 'Quetta'],
#  'Zip Code': [1, 2, 3, 4],
#  'Population': ['1234', '65768', '56743', '2345']}

# %%
df1=pd.DataFrame(dict1)
df1
# Out:
#      City  Zip Code Population
# 0     khi         1       1234
# 1     lah         2      65768
# 2     Isl         3      56743
# 3  Quetta         4       2345

# %%
df1=pd.DataFrame(dict1,index=['a','b','c','d'])
df1
# Out:
#      City  Zip Code Population
# a     khi         1       1234
# b     lah         2      65768
# c     Isl         3      56743
# d  Quetta         4       2345

# %%
df1=pd.DataFrame(dict1,index=['a','b','c','d'],columns=["population","Zip Code","City"])
df1
# Out:
#   population  Zip Code    City
# a        NaN         1     khi
# b        NaN         2     lah
# c        NaN         3     Isl
# d        NaN         4  Quetta

# %%
df1["City"]
# Out:
# a       khi
# b       lah
# c       Isl
# d    Quetta
# Name: City, dtype: object

# %%
df1["City"]["c"]="Faislabad"
# Out:
# C:\Users\me\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1=pd.DataFrame(dict1,index=['a','b','c','d'],columns=["population",
                                                        "Zip Code","City","Covered Area"])
df1
# Out:
#   population  Zip Code    City Covered Area
# a        NaN         1     khi          NaN
# b        NaN         2     lah          NaN
# c        NaN         3     Isl          NaN
# d        NaN         4  Quetta          NaN

# %%
df1["postal"]=123

# %%
df1
# Out:
#   population  Zip Code    City Covered Area  postal
# a        NaN         1     khi          NaN     123
# b        NaN         2     lah          NaN     123
# c        NaN         3     Isl          NaN     123
# d        NaN         4  Quetta          NaN     123

# %%
df1["City"]["a"]
# Out:
# 'khi'

# %%
df1.loc['c']
# Out:
# population      NaN
# Zip Code          3
# City            Isl
# Covered Area    NaN
# postal          123
# Name: c, dtype: object

# %%
df1.iloc[2]
# Out:
# population      NaN
# Zip Code          3
# City            Isl
# Covered Area    NaN
# postal          123
# Name: c, dtype: object

# %%
df1["City"][2]
# Out:
# 'Isl'

# %%
df1.loc['b':'d']
# Out:
#   population  Zip Code    City Covered Area  postal
# b        NaN         2     lah          NaN     123
# c        NaN         3     Isl          NaN     123
# d        NaN         4  Quetta          NaN     123

# %%
df1.iloc[1:3]
# Out:
#   population  Zip Code City Covered Area  postal
# b        NaN         2  lah          NaN     123
# c        NaN         3  Isl          NaN     123

# %%
df1.loc[['b','c','d']]
# Out:
#   population  Zip Code    City Covered Area  postal
# b        NaN         2     lah          NaN     123
# c        NaN         3     Isl          NaN     123
# d        NaN         4  Quetta          NaN     123

# %%
df1.iloc[[1,2,3]]
# Out:
#   population  Zip Code    City Covered Area  postal
# b        NaN         2     lah          NaN     123
# c        NaN         3     Isl          NaN     123
# d        NaN         4  Quetta          NaN     123

# %%
df1.iloc[[2,1,3]]
# Out:
#   population  Zip Code    City Covered Area  postal
# c        NaN         3     Isl          NaN     123
# b        NaN         2     lah          NaN     123
# d        NaN         4  Quetta          NaN     123

# %%
df1["Zip Code"]>2#on simple condition give boolean value
# Out:
# a    False
# b    False
# c     True
# d     True
# Name: Zip Code, dtype: bool

# %%
df1[df1["Zip Code"]>2]
# Out:
#   population  Zip Code    City Covered Area  postal
# c        NaN         3     Isl          NaN     123
# d        NaN         4  Quetta          NaN     123

# %% [markdown]
# # Function Application with mapping

# %%
df.sort_index()
# Out:
#          0
# 0    Apple
# 1  Mangoes
# 2   Banana

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4))
                    ,index=['Ohio', 'Colorado', 'Utah', 'New York'], 
                                        columns=['one', 'two', 'three', 'four'])

# %%
import numpy as np

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.sort_index()
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# New York   12   13     14    15
# Ohio        0    1      2     3
# Utah        8    9     10    11

# %%
data.sort_index(ascending=False)
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# Ohio        0    1      2     3
# New York   12   13     14    15
# Colorado    4    5      6     7

# %%
data1 = pd.DataFrame(np.arange(8,0,-1).reshape((4, 2))
                    ,index=['Ohio', 'Colorado', 'Utah', 'New York'], 
                                        columns=['one', 'two'])

# %%
data1
# Out:
#           one  two
# Ohio        8    7
# Colorado    6    5
# Utah        4    3
# New York    2    1

# %%
data1.sort_values(by='two')
# Out:
#           one  two
# New York    2    1
# Utah        4    3
# Colorado    6    5
# Ohio        8    7

# %%
pd.options.display.max_rows=10

# %%
csvdata=pd.read_csv('jTeOBO.csv')
csvdata.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
frame=pd.DataFrame(csvdata)
frame
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 1   022-14-110233  BS(CS)        Adeel Ahmed   17     NaN     5.0
# 2   022-14-110585  BS(CS)       Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)     Ahmed Ali Raza   14     7.0     2.0
# 4   022-14-110648  BS(CS)    Ahsan Ali Vohra   27     7.0     6.0
# ..            ...     ...                ...  ...     ...     ...
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# ...

# %%
frame.sort_values(by="Best of Quizzes")
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# ...

# %%
frame.sort_values(by=["Best of Quizzes","Student Name"],ascending=False)
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 47  022-14-110219  BS(CS)                     Waqar Ahmed   11     9.0
# 45  022-14-110400  BS(CS)               Syeda Sabika Raza   27     9.0
# 43  022-14-110451  BS(CS)               Syed Faizan Uddin   28     9.0
# 40  022-14-110584  BS(CS)                     Sharif Taqi   27     9.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# 36  022-14-110582  BS(CS)                      Rida Nasim   25     9.0
# 34  022-14-110413  BS(CS)                Nazeer Bin Zafar   25     9.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# ...

# %%
#do columns may 
frame.sort_values(by=["Best of Quizzes","Student Name"])
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# ...

# %%
frame.sort_values(by=["Best of Quizzes","Assignment 1"])
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# ...

# %%
frame.sort_values(by=["Best of Quizzes","Student Name"],inplace =True)
#jahan data load kiya tha wahan changes hongi
frame
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# ...

# %%
frame=frame.sort_values(by=["Student Code","Total (100)"])
#jahan data load kiya tha wahan changes hongi

# %%
frame
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 29  022-14-110217  BS(CS)       Muhammad Shahroz Khurshid   17     7.0
# 47  022-14-110219  BS(CS)                     Waqar Ahmed   11     9.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 41  022-14-110225  BS(CS)                   Shariqa Ahmad   20     7.0
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 37  022-14-110230  BS(CS)                   Sadaf Nosheen   27     9.0
# ...

# %%
pd.options.display.max_rows=10

# %%
obj=pd.Series([78,90,87,65,43,21])
obj
# Out:
# 0    78
# 1    90
# 2    87
# 3    65
# 4    43
# 5    21
# dtype: int64

# %%
obj.sort_values(inplace=True)

# %%
obj
# Out:
# 5    21
# 4    43
# 3    65
# 0    78
# 2    87
# 1    90
# dtype: int64

# %%
obj.rank(method="first")#if values is same it can consider the index
# Out:
# 5    1.0
# 4    2.0
# 3    3.0
# 0    4.0
# 2    5.0
# 1    6.0
# dtype: float64

# %%
obj1=pd.Series([2,4,5,7,2,9])
obj1
# Out:
# 0    2
# 1    4
# 2    5
# 3    7
# 4    2
# 5    9
# dtype: int64

# %%
obj1.sort_values(inplace=True)
obj1
# Out:
# 0    2
# 4    2
# 1    4
# 2    5
# 3    7
# 5    9
# dtype: int64

# %%
 obj1.rank()#provide average to the same value((1+2)/2)

# %%
obj1.rank(method="first")
# Out:
# 0    1.0
# 4    2.0
# 1    3.0
# 2    4.0
# 3    5.0
# 5    6.0
# dtype: float64

# %%
arr =np.array([2,3,4,5,7,9])

# %%
np.max(arr)
# Out:
# 9

# %%
np.min(arr)
# Out:
# 2

# %%
arr.max()
# Out:
# 9

# %%
arr.min()
# Out:
# 2

# %%
print(f"The max value is {arr.max()}")
print()
print(f"The index of max is {arr.argmax()}")
# Out:
# The max value is 9
#
# The index of max is 5

# %%
print(f"The min value is {arr.min()}")
print()
print(f"The index of min is {arr.argmin()}")
# Out:
# The min value is 2
#
# The index of min is 0

# %%
frame["Mid"].max()
# Out:
# 30

# %%
frame["Mid"].idxmax()
# Out:
# 10

# %%
frame["Mid"].cumsum()
# Out:
# 0       28
# 1       45
# 2       63
# 3       77
# 4      104
#       ...
# 43    1013
# 44    1038
# 45    1065
# 46    1090
# 47    1101
# Name: Mid, Length: 48, dtype: int64

# %%
import pandas_datareader.data as web

# %%
all_data = {ticker: web.get_data_yahoo(ticker)  
            for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}

# %%
all_data
# Out:
# {'AAPL':                   High         Low        Open       Close      Volume  \
#  Date
#  2014-10-27  105.480003  104.699997  104.849998  105.110001  34187700.0
#  2014-10-28  106.739998  105.349998  105.400002  106.739998  48060900.0
#  2014-10-29  107.370003  106.360001  106.650002  107.339996  52687900.0
#  2014-10-30  107.349998  105.900002  106.959999  106.980003  40654800.0
#  2014-10-31  108.040001  107.209999  108.010002  108.000000  44639300.0
#  ...                ...         ...         ...         ...         ...
#  2019-10-21  240.990005  237.320007  237.520004  240.509995  21811800.0
#  2019-10-22  242.199997  239.619995  241.160004  239.960007  20573400.0
#  2019-10-23  243.240005  241.220001  242.100006  243.179993  18957200.0
#  2019-10-24  244.800003  241.809998  244.509995  243.580002  17318800.0
#  2019-10-25  246.729996  242.880005  243.160004  246.580002  18330500.0
#
#               Adj Close
#  Date
#  2014-10-27   96.448616
#  2014-10-28   97.944298
# ...

# %%
all_data.keys()
# Out:
# dict_keys(['AAPL', 'IBM', 'MSFT', 'GOOG'])

# %%
all_data["AAPL"]
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2014-10-27  105.480003  104.699997  104.849998  105.110001  34187700.0
# 2014-10-28  106.739998  105.349998  105.400002  106.739998  48060900.0
# 2014-10-29  107.370003  106.360001  106.650002  107.339996  52687900.0
# 2014-10-30  107.349998  105.900002  106.959999  106.980003  40654800.0
# 2014-10-31  108.040001  107.209999  108.010002  108.000000  44639300.0
# ...                ...         ...         ...         ...         ...
# 2019-10-21  240.990005  237.320007  237.520004  240.509995  21811800.0
# 2019-10-22  242.199997  239.619995  241.160004  239.960007  20573400.0
# 2019-10-23  243.240005  241.220001  242.100006  243.179993  18957200.0
# 2019-10-24  244.800003  241.809998  244.509995  243.580002  17318800.0
# 2019-10-25  246.729996  242.880005  243.160004  246.580002  18330500.0
#
#              Adj Close
# Date
# 2014-10-27   96.448616
# 2014-10-28   97.944298
# 2014-10-29   98.494850
# ...

# %%
price = pd.DataFrame({ticker: data['Adj Close']         
                      for ticker, data in all_data.items()})

# %%
price
# Out:
#                   AAPL         IBM        MSFT         GOOG
# Date
# 2014-10-27   96.448616  131.081451   41.097130   539.289368
# 2014-10-28   97.944298  132.482391   41.616329   547.397095
# 2014-10-29   98.494850  132.369003   41.732697   547.825928
# 2014-10-30   98.164513  133.089706   41.222458   548.803284
# 2014-10-31   99.100471  133.130219   42.028111   557.549255
# ...                ...         ...         ...          ...
# 2019-10-21  240.509995  132.580002  138.429993  1246.150024
# 2019-10-22  239.960007  133.960007  136.369995  1242.800049
# 2019-10-23  243.179993  134.380005  137.240005  1259.130005
# 2019-10-24  243.580002  134.070007  139.940002  1260.989990
# 2019-10-25  246.580002  135.440002  140.729996  1265.130005
#
# [1259 rows x 4 columns]

# %%
volume = pd.DataFrame({ticker: data['Volume']   
                       for ticker, data in all_data.items()})

# %%
volume
# Out:
#                   AAPL        IBM        MSFT       GOOG
# Date
# 2014-10-27  34187700.0  4989100.0  30371300.0  1185300.0
# 2014-10-28  48060900.0  7895300.0  29049800.0  1270900.0
# 2014-10-29  52687900.0  4739300.0  30276100.0  1770500.0
# 2014-10-30  40654800.0  3896000.0  30073900.0  1455600.0
# 2014-10-31  44639300.0  5818000.0  35849700.0  2035000.0
# ...                ...        ...         ...        ...
# 2019-10-21  21811800.0  6306100.0  20078200.0  1027200.0
# 2019-10-22  20573400.0  4161600.0  27431000.0  1023800.0
# 2019-10-23  18957200.0  3610900.0  29844600.0   911500.0
# 2019-10-24  17318800.0  2598500.0  37029300.0  1028100.0
# 2019-10-25  18330500.0  2578000.0  25274600.0  1210100.0
#
# [1259 rows x 4 columns]

# %%
returns =price.pct_change()

# %%
returns
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2014-10-27       NaN       NaN       NaN       NaN
# 2014-10-28  0.015508  0.010688  0.012633  0.015034
# 2014-10-29  0.005621 -0.000856  0.002796  0.000783
# 2014-10-30 -0.003354  0.005445 -0.012226  0.001784
# 2014-10-31  0.009535  0.000304  0.019544  0.015936
# ...              ...       ...       ...       ...
# 2019-10-21  0.017343 -0.011261  0.007423  0.000530
# 2019-10-22 -0.002287  0.010409 -0.014881 -0.002688
# 2019-10-23  0.013419  0.003135  0.006380  0.013140
# 2019-10-24  0.001645 -0.002307  0.019674  0.001477
# 2019-10-25  0.012316  0.010219  0.005645  0.003283
#
# [1259 rows x 4 columns]

# %%
returns['MSFT'].corr(returns['IBM'])
# Out:
# 0.4859044237050968

# %%
returns['MSFT'].cov(returns['IBM'])
# Out:
# 9.367689618560126e-05

# %%
returns.corr()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.405686  0.572626  0.520823
# IBM   0.405686  1.000000  0.485904  0.412926
# MSFT  0.572626  0.485904  1.000000  0.655260
# GOOG  0.520823  0.412926  0.655260  1.000000

# %%
returns.cov()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  0.000246  0.000083  0.000133  0.000124
# IBM   0.000083  0.000170  0.000094  0.000082
# MSFT  0.000133  0.000094  0.000219  0.000147
# GOOG  0.000124  0.000082  0.000147  0.000230

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c']) 
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)
